# %% [markdown]
# # Getting the Data

# %% [markdown]
# ### Best Picture Table from Wikipedia

# %%
#import library to query webpage of interest
import urllib.request
#specifying page of interest
wiki = "https://en.wikipedia.org/wiki/Academy_Award_for_Best_Picture"
    
#save the HTML of the site within the page variable
page = urllib.request.urlopen(wiki)

#import library to parse HTML from page
from bs4 import BeautifulSoup

#parse data from "page" and save to new variable "soup"
soup = BeautifulSoup(page, 'lxml')

# %%
#pinpointing the location of the table and its contents
tables = soup.findAll("table", class_ = "wikitable")

#creating lists for each of the columns I know to be in my table.
films=[]
studios=[]

#utilizing HTML tags for rows <tr> and elements <td> to 
# iterate through each row of data and append data elements to their appropriate lists:
for table in tables:
    for row in table.findAll("tr"):
        cells = row.findAll("td")
        if len(cells)==2: #Only extract table body not heading
            films.append(cells[0].find(text=True).strip())
            studios.append(cells[1].find(text=True).strip())

# %%
import pandas as pd

# %% [markdown]
# ### Creating DataFrames

# %%
df_films = pd.DataFrame(films)
df_films['Winner'] = 0
df_films.columns = ['Film', 'Winner']

# %% [markdown]
# ### Dummy Variable for Eventual Winners

# %%
df_films.loc[df_films['Film'] == 'Wings','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Broadway Melody','Winner'] = 1
df_films.loc[df_films['Film'] == 'All Quiet on the Western Front','Winner'] = 1
df_films.loc[df_films['Film'] == 'Cimarron','Winner'] = 1
df_films.loc[df_films['Film'] == 'Grand Hotel','Winner'] = 1
df_films.loc[df_films['Film'] == 'Cavalcade','Winner'] = 1
df_films.loc[df_films['Film'] == 'It Happened One Night','Winner'] = 1
df_films.loc[df_films['Film'] == 'Mutiny on the Bounty','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Great Ziegfeld','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Life of Emile Zola','Winner'] = 1
df_films.loc[df_films['Film'] == "You Can't Take It with You",'Winner'] = 1
df_films.loc[df_films['Film'] == 'Gone with the Wind','Winner'] = 1
df_films.loc[df_films['Film'] == 'Rebecca','Winner'] = 1
df_films.loc[df_films['Film'] == 'How Green Was My Valley','Winner'] = 1
df_films.loc[df_films['Film'] == 'Mrs. Miniver','Winner'] = 1
df_films.loc[df_films['Film'] == 'Casablanca','Winner'] = 1
df_films.loc[df_films['Film'] == 'Going My Way','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Lost Weekend','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Best Years of Our Lives','Winner'] = 1
df_films.loc[df_films['Film'] == "Gentleman's Agreement",'Winner'] = 1
df_films.loc[df_films['Film'] == 'Hamlet','Winner'] = 1
df_films.loc[df_films['Film'] == "All the King's Men",'Winner'] = 1
df_films.loc[df_films['Film'] == 'All About Eve','Winner'] = 1
df_films.loc[df_films['Film'] == 'An American in Paris','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Greatest Show on Earth','Winner'] = 1
df_films.loc[df_films['Film'] == 'From Here to Eternity','Winner'] = 1
df_films.loc[df_films['Film'] == 'On the Waterfront','Winner'] = 1
df_films.loc[df_films['Film'] == 'Marty','Winner'] = 1
df_films.loc[df_films['Film'] == 'Around the World in 80 Days','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Bridge on the River Kwai','Winner'] = 1
df_films.loc[df_films['Film'] == 'Gigi','Winner'] = 1
df_films.loc[df_films['Film'] == 'Ben-Hur','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Apartment','Winner'] = 1
df_films.loc[df_films['Film'] == 'West Side Story','Winner'] = 1
df_films.loc[df_films['Film'] == 'Lawrence of Arabia','Winner'] = 1
df_films.loc[df_films['Film'] == 'Tom Jones','Winner'] = 1
df_films.loc[df_films['Film'] == 'My Fair Lady','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Sound of Music','Winner'] = 1
df_films.loc[df_films['Film'] == 'A Man for All Seasons','Winner'] = 1
df_films.loc[df_films['Film'] == 'In the Heat of the Night','Winner'] = 1
df_films.loc[df_films['Film'] == 'Oliver!','Winner'] = 1
df_films.loc[df_films['Film'] == 'Midnight Cowboy','Winner'] = 1
df_films.loc[df_films['Film'] == 'Patton','Winner'] = 1
df_films.loc[df_films['Film'] == 'The French Connection','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Godfather','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Sting','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Godfather Part II','Winner'] = 1
df_films.loc[df_films['Film'] == "One Flew Over the Cuckoo's Nest",'Winner'] = 1
df_films.loc[df_films['Film'] == 'Rocky','Winner'] = 1
df_films.loc[df_films['Film'] == 'Annie Hall','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Deer Hunter','Winner'] = 1
df_films.loc[df_films['Film'] == 'Kramer vs. Kramer','Winner'] = 1
df_films.loc[df_films['Film'] == 'Ordinary People','Winner'] = 1
df_films.loc[df_films['Film'] == 'Chariots of Fire','Winner'] = 1
df_films.loc[df_films['Film'] == 'Gandhi','Winner'] = 1
df_films.loc[df_films['Film'] == 'Terms of Endearment','Winner'] = 1
df_films.loc[df_films['Film'] == 'Amadeus','Winner'] = 1
df_films.loc[df_films['Film'] == 'Out of Africa','Winner'] = 1
df_films.loc[df_films['Film'] == 'Platoon','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Last Emperor','Winner'] = 1
df_films.loc[df_films['Film'] == 'Rain Man','Winner'] = 1
df_films.loc[df_films['Film'] == 'Driving Miss Daisy','Winner'] = 1
df_films.loc[df_films['Film'] == 'Dances with Wolves','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Silence of the Lambs','Winner'] = 1
df_films.loc[df_films['Film'] == 'Unforgiven','Winner'] = 1
df_films.loc[df_films['Film'] == "Schindler's List",'Winner'] = 1
df_films.loc[df_films['Film'] == 'Forrest Gump','Winner'] = 1
df_films.loc[df_films['Film'] == 'Braveheart','Winner'] = 1
df_films.loc[df_films['Film'] == 'The English Patient','Winner'] = 1
df_films.loc[df_films['Film'] == 'Titanic','Winner'] = 1
df_films.loc[df_films['Film'] == 'Shakespeare in Love','Winner'] = 1
df_films.loc[df_films['Film'] == 'American Beauty','Winner'] = 1
df_films.loc[df_films['Film'] == 'Gladiator','Winner'] = 1
df_films.loc[df_films['Film'] == 'A Beautiful Mind','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Lord of the Rings: The Return of the King','Winner'] = 1
df_films.loc[df_films['Film'] == 'Chicago','Winner'] = 1
df_films.loc[df_films['Film'] == 'Million Dollar Baby','Winner'] = 1
df_films.loc[df_films['Film'] == 'Crash','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Departed','Winner'] = 1
df_films.loc[df_films['Film'] == 'No Country for Old Men','Winner'] = 1
df_films.loc[df_films['Film'] == 'Slumdog Millionaire']['Winner'] = 1
df_films.loc[df_films['Film'] == 'The Hurt Locker','Winner'] = 1
df_films.loc[df_films['Film'] == "The King's Speech",'Winner'] = 1
df_films.loc[df_films['Film'] == 'The Artist','Winner'] = 1
df_films.loc[df_films['Film'] == 'Argo','Winner'] = 1
df_films.loc[df_films['Film'] == '12 Years a Slave','Winner'] = 1
df_films.loc[df_films['Film'] == 'Birdman or (The Unexpected Virtue of Ignorance)','Winner'] = 1
df_films.loc[df_films['Film'] == 'Spotlight','Winner'] = 1
df_films.loc[df_films['Film'] == 'Moonlight','Winner'] = 1
df_films.loc[df_films['Film'] == 'The Shape of Water','Winner'] = 1
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_films.head()
# Out:
#                   Film  Winner
# 0                Wings       1
# 1           The Racket       0
# 2           7th Heaven       0
# 3  The Broadway Melody       1
# 4                Alibi       0

# %% [markdown]
# ### Combining with IMDb Dataset

# %%
imdb_data = pd.read_csv('~/Documents/Kaggle + Hackathons/title.basics.tsv', sep='\t', low_memory = False)

# %%
imdb_data = imdb_data[imdb_data['titleType'] == 'movie']

# %%
imdb_data.rename(columns={'primaryTitle':'Film'}, inplace=True)

# %%
imdb_data.head()
# Out:
#         tconst titleType                           Film  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry        0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight        0      1897      \N             20
# 332          Soldiers of the Cross        0      1900      \N             \N
# 499                       Bohemios        0      1905      \N            100
# 571    The Story of the Kelly Gang        0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# 571   Biography,Crime,Drama

# %%
combined_data = df_films.merge(imdb_data[['Film', 'runtimeMinutes', 'genres', 'startYear']],
                               how='left', on='Film')

# %%
combined_data = combined_data[(combined_data['startYear'] != '\\N')]

# %%
combined_data = combined_data[(combined_data['runtimeMinutes'] != '\\N')]

# %% [markdown]
# ### Cleaning 'title' Discrepancies between the Datasets

# %%
# names not matching
# need to manually edit these
combined_data[combined_data['runtimeMinutes'].isna()]
# Out:
#                                                   Film  Winner runtimeMinutes  \
# 22                                     Hollywood Revue       0            NaN
# 95                      The Private Life of Henry VIII       0            NaN
# 691   The Russians Are Coming, the Russians Are Coming       0            NaN
# 779                                 Cries and Whispers       0            NaN
# 782                              The Godfather Part II       1            NaN
# 829                                          Star Wars       0            NaN
# 884                         E.T. the Extra-Terrestrial       0            NaN
# 975                             The Godfather Part III       0            NaN
# 1031                          The Postman (Il Postino)       0            NaN
# 1129                         Good Night, and Good Luck       0            NaN
# 1172   Precious: Based on the Novel 'Push' by Sapphire       0            NaN
#
#      genres startYear
# 22      NaN       NaN
# 95      NaN       NaN
# 691     NaN       NaN
# 779     NaN       NaN
# 782     NaN       NaN
# 829     NaN       NaN
# 884     NaN       NaN
# 975     NaN       NaN
# 1031    NaN       NaN
# 1129    NaN       NaN
# 1172    NaN       NaN

# %%
df_films.loc[df_films['Film'] == 'Hollywood Revue', 'Film'] = 'The Hollywood Revue of 1929'
df_films.loc[df_films['Film'] == 'The Private Life of Henry VIII', 'Film'] = 'The Private Life of Henry VIII.'
df_films.loc[df_films['Film'] == 'The Russians Are Coming, the Russians Are Coming', 'Film'] = 'The Russians Are Coming! The Russians Are Coming!'
df_films.loc[df_films['Film'] == 'Cries and Whispers', 'Film'] = 'Cries & Whispers'
df_films.loc[df_films['Film'] == 'The Godfather Part II', 'Film'] = 'The Godfather: Part II'
df_films.loc[df_films['Film'] == 'Star Wars', 'Film'] = 'Star Wars: Episode IV - A New Hope'
df_films.loc[df_films['Film'] == 'E.T. the Extra-Terrestrial', 'Film'] = 'E.T. The Extra-Terrestrial'
df_films.loc[df_films['Film'] == 'The Godfather Part III', 'Film'] = 'The Godfather: Part III'
df_films.loc[df_films['Film'] == 'The Postman (Il Postino)', 'Film'] = 'Il Postino: The Postman'
df_films.loc[df_films['Film'] == 'Good Night, and Good Luck', 'Film'] = 'Good Night, and Good Luck.'
df_films.loc[df_films['Film'] == "Precious: Based on the Novel 'Push' by Sapphire", 'Film'] = 'Precious'

# %%
combined_data1 = df_films.merge(imdb_data[['Film', 'runtimeMinutes', 'genres', 'startYear']],
                               how='left', on='Film')

# %%
combined_data1 = combined_data1[(combined_data1['startYear'] != '\\N')]
combined_data1 = combined_data1[(combined_data1['runtimeMinutes'] != '\\N')]

# %%
combined_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1077 entries, 0 to 1349
# Data columns (total 5 columns):
# Film              1077 non-null object
# Winner            1077 non-null int64
# runtimeMinutes    1077 non-null object
# genres            1077 non-null object
# startYear         1077 non-null object
# dtypes: int64(1), object(4)
# memory usage: 50.5+ KB

# %% [markdown]
# ### Removing Duplicate 'Titles'

# %%
clean_df = combined_data1.drop_duplicates(subset='Film')

# %%
# missing 6 movies that are removed as duplicates
# need to add those 6 manually
len(clean_df)
# Out:
# 548

# %%
df_films['Film'].value_counts()[0:6]
# Out:
# Romeo and Juliet        2
# Cleopatra               2
# Les Misérables          2
# Heaven Can Wait         2
# Mutiny on the Bounty    2
# A Star Is Born          2
# Name: Film, dtype: int64

# %%
# manually looked at movies that appeared more than once and were deleted
# added them manually

clean_df = clean_df.append(combined_data1.loc[[1342, 715, 1239, 652, 131, 857]])

# %%
clean_df.rename(columns={'runtimeMinutes':'Duration', 'startYear':'Year', 'genres':'Genre'}, 
                inplace=True)

# %%
clean_df.index = range(len(clean_df))

# %%
clean_df.head()
# Out:
#                   Film  Winner Duration                  Genre  Year
# 0                Wings       1      144   Action,Drama,Romance  1927
# 1           The Racket       0       84  Crime,Drama,Film-Noir  1928
# 2           7th Heaven       0      110          Drama,Romance  1927
# 3  The Broadway Melody       1      100  Drama,Musical,Romance  1929
# 4                Alibi       0       91                  Crime  1929

# %% [markdown]
# ### Correcting for Movies Released in Correct Year

# %%
# 29 movies replaced with wrong movie due to same name issue
# need to replace these with proper year movies
clean_df[clean_df['Year'] < '1927']
# Out:
#                             Film  Winner Duration                     Genre  \
# 7                    The Patriot       0       50                   Western
# 10                      Disraeli       0       70           Biography,Drama
# 11                  The Divorcee       0       50                     Drama
# 14                    East Lynne       0       75                     Drama
# 31                  Little Women       0       60      Drama,Family,Romance
# 34               Smilin' Through       0       96                     Drama
# 38                     Cleopatra       0      100             Drama,History
# 49                   Alice Adams       0       73                     Drama
# 51                 Captain Blood       0      110  Action,Adventure,Romance
# 56                Les Misérables       0      100                     Drama
# 58            Ruggles of Red Gap       0       80            Comedy,Western
# 65              Romeo and Juliet       0       70                     Drama
# 68          A Tale of Two Cities       0       70     Drama,History,Romance
# 71               The Awful Truth       0       60                    Comedy
# 98              The Wizard of Oz       0       81   Adventure,Comedy,Family
# 99             Wuthering Heights       0       90                     Drama
# 119                    Suspicion       0       60                     Drama
# 127         The Talk of the Town       0       60            Comedy,Romance
# 158           Great Expectations       0       50                     Drama
# 160                       Hamlet       1       64                     Drama
# 182                      Ivanhoe       0       53   Adventure,Drama,Romance
# 186                Julius Caesar       0      112             Drama,History
# 200  Around the World in 80 Days       1      121                        \N
# 204         The Ten Commandments       0      136   Biography,Drama,Fantasy
# 237          Lilies of the Field       0       90                     Drama
# 279                  Deliverance       0       90           Biography,Drama
# 328                      Missing       0       50                 Drama,War
# 391                   Braveheart       1       71                   Western
# 474                  The Fighter       0       50                     Drama
#
#      Year
# 7    1916
# 10   1921
# 11   1919
# 14   1916
# 31   1918
# 34   1922
# 38   1912
# 49   1923
# 51   1924
# 56   1917
# 58   1923
# 65   1916
# 68   1917
# 71   1925
# 98   1925
# 99   1920
# 119  1918
# 127  1918
# 158  1917
# 160  1913
# 182  1913
# 186  1914
# 200  1919
# 204  1923
# 237  1924
# 279  1919
# 328  1918
# 391  1925
# 474  1921

# %%
winners = clean_df[['Film','Winner']]

# %%
clean_df.drop(columns='Winner', inplace=True)

# %%
y = imdb_data.loc[(imdb_data['Film'] == 'The Patriot') & (imdb_data['startYear'] == '1928'), \
               ['Film','runtimeMinutes', 'genres','startYear']]
clean_df.loc[clean_df['Film'] == 'The Patriot'] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == 'Disraeli') & (imdb_data['startYear'] == '1929'), ['Film','runtimeMinutes', 'genres','startYear']]
clean_df.loc[clean_df['Film'] == 'Disraeli'] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == 'The Divorcee') & (imdb_data['startYear'] == '1930'),
                 ['Film','runtimeMinutes', 'genres','startYear']]

# %%
clean_df.loc[clean_df['Film'] == 'The Divorcee'] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == 'East Lynne') & 
                                                            (imdb_data['startYear'] == '1931'),
                 ['Film','runtimeMinutes', 'genres','startYear']]


clean_df.loc[clean_df['Film'] == 'East Lynne'] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == 'Little Women') & 
                                                            (imdb_data['startYear'] == '1933'),
                 ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == 'Little Women'] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Smilin' Through") & 
                                                            (imdb_data['startYear'] == '1932'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Smilin' Through"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Cleopatra") & 
                                                            (imdb_data['startYear'] == '1934'),
                ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[(clean_df['Film'] == "Cleopatra") & (clean_df['Year'] == '1912')]=y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Alice Adams") & 
                                                            (imdb_data['startYear'] == '1935'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Alice Adams"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Captain Blood") & 
                                                            (imdb_data['startYear'] == '1935'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Captain Blood"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Les Misérables") & 
                                                            (imdb_data['startYear'] == '1935'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[(clean_df['Film'] == "Les Misérables") & (clean_df['Year'] < '2000')] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Ruggles of Red Gap") & 
                                                            (imdb_data['startYear'] == '1935'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Ruggles of Red Gap"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Romeo and Juliet") & 
                                                            (imdb_data['startYear'] == '1936'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[(clean_df['Film'] == "Romeo and Juliet") & (clean_df['Year'] < '1945')] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "A Tale of Two Cities") & 
                                                            (imdb_data['startYear'] == '1935'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "A Tale of Two Cities"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "The Awful Truth") & 
                                                            (imdb_data['startYear'] == '1937'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "The Awful Truth"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "The Wizard of Oz") & 
                                                            (imdb_data['startYear'] == '1939'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "The Wizard of Oz"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Wuthering Heights") & 
                                                            (imdb_data['startYear'] == '1939'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Wuthering Heights"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Suspicion") & 
                                                            (imdb_data['startYear'] == '1941'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Suspicion"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "The Talk of the Town") & 
                                                            (imdb_data['startYear'] == '1942'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "The Talk of the Town"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Great Expectations") & 
                                                            (imdb_data['startYear'] == '1946'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Great Expectations"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Hamlet") & 
                                                            (imdb_data['startYear'] == '1948'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Hamlet"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Ivanhoe") & 
                                                            (imdb_data['startYear'] == '1952'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Ivanhoe"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Julius Caesar") & 
                                                            (imdb_data['startYear'] == '1953'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Julius Caesar"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Around the World in 80 Days") & 
                                                            (imdb_data['startYear'] == '1956'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Around the World in 80 Days"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "The Ten Commandments") & 
                                                            (imdb_data['startYear'] == '1956'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "The Ten Commandments"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Lilies of the Field") & 
                                                            (imdb_data['startYear'] == '1963'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Lilies of the Field"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Deliverance") & 
                                                            (imdb_data['startYear'] == '1972'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Deliverance"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Missing") & 
                                                            (imdb_data['startYear'] == '1982'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Missing"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "Braveheart") & 
                                                            (imdb_data['startYear'] == '1995'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "Braveheart"] = y.values

# %%
y = imdb_data.loc[(imdb_data['Film'] == "The Fighter") & 
                                                            (imdb_data['startYear'] == '2010'),
         ['Film','runtimeMinutes', 'genres','startYear']]

clean_df.loc[clean_df['Film'] == "The Fighter"] = y.values

# %%
clean_df[clean_df['Year'] < '1927']
# Out:
# Empty DataFrame
# Columns: [Film, Duration, Genre, Year]
# Index: []

# %%
final_df = clean_df.merge(winners, how='left', left_index=True, right_index=True)

# %%
final_df.drop(columns='Film_y', inplace=True)

# %%
final_df.rename(columns={'Film_x':'Film'}, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 554 entries, 0 to 553
# Data columns (total 5 columns):
# Film        554 non-null object
# Duration    554 non-null object
# Genre       554 non-null object
# Year        554 non-null object
# Winner      554 non-null int64
# dtypes: int64(1), object(4)
# memory usage: 21.7+ KB

# %%
final_df.head(10)
# Out:
#                              Film Duration                  Genre  Year  \
# 0                           Wings      144   Action,Drama,Romance  1927
# 1                      The Racket       84  Crime,Drama,Film-Noir  1928
# 2                      7th Heaven      110          Drama,Romance  1927
# 3             The Broadway Melody      100  Drama,Musical,Romance  1929
# 4                           Alibi       91                  Crime  1929
# 5     The Hollywood Revue of 1929      130                Musical  1929
# 6                  In Old Arizona       95        Romance,Western  1928
# 7                     The Patriot      113                  Drama  1928
# 8  All Quiet on the Western Front      136              Drama,War  1930
# 9                   The Big House       87   Crime,Drama,Thriller  1930
#
#    Winner
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       0
# 8       1
# 9       0

# %%
final_df['Biopic'] = 0

# %%
def biopic(series):
    if 'Biography' in series.split(','):
        return 1
    else:
        return 0

final_df['Biopic'] = final_df['Genre'].apply(biopic)

# %%
final_df['Year'] = pd.to_datetime(final_df['Year'], format='%Y')
#final_df['Year'] = final_df['Year'].apply(lambda x:x.year)

# %%
final_df['Duration'] = final_df['Duration'].astype(dtype='int64')

# %%
def split_genre(series):
    genres = series.split(',')
    for i in range(len(genres)):
        print(genres[i])
        r = final_df['Genre'+str(i+1)] = genres[i]
    return None

# %%
final_df.head()
# Out:
#                   Film  Duration                  Genre       Year  Winner  \
# 0                Wings       144   Action,Drama,Romance 1927-01-01       1
# 1           The Racket        84  Crime,Drama,Film-Noir 1928-01-01       0
# 2           7th Heaven       110          Drama,Romance 1927-01-01       0
# 3  The Broadway Melody       100  Drama,Musical,Romance 1929-01-01       1
# 4                Alibi        91                  Crime 1929-01-01       0
#
#    Biopic
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
final_df
# Out:
#                                           Film  Duration  \
# 0                                        Wings       144
# 1                                   The Racket        84
# 2                                   7th Heaven       110
# 3                          The Broadway Melody       100
# 4                                        Alibi        91
# 5                  The Hollywood Revue of 1929       130
# 6                               In Old Arizona        95
# 7                                  The Patriot       113
# 8               All Quiet on the Western Front       136
# 9                                The Big House        87
# 10                                    Disraeli        90
# 11                                The Divorcee        84
# 12                             The Love Parade       107
# 13                                    Cimarron       123
# 14                                  East Lynne       102
# 15                              The Front Page       101
# 16                                      Skippy        85
# 17                                 Trader Horn       122
# 18                                 Grand Hotel       112
# 19                                  Arrowsmith       108
# 20                                    Bad Girl        90
# 21                                   The Champ        86
# 22                             Five Star Final        89
# 23                           One Hour with You        80
# 24                            Shanghai Express        82
# 25                      The Smiling Lieutenant        93
# 26                                   Cavalcade       112
# 27                                 42nd Street        89
# 28                          A Farewell to Arms        80
# 29           I Am a Fugitive from a Chain Gang        92
# ..                                         ...       ...
# 524                                    Arrival       116
# 525                                     Fences       139
# 526                              Hacksaw Ridge       139
# 527                         Hell or High Water       102
# 528                             Hidden Figures       127
# 529                                 La La Land       128
# 530                                       Lion        70
# 531                      Manchester by the Sea       137
# 532                         The Shape of Water        70
# 533                       Call Me by Your Name       132
# 534                               Darkest Hour        96
# 535                                    Dunkirk       135
# 536                                    Get Out       104
# 537                                  Lady Bird        94
# 538                             Phantom Thread       130
# 539                                   The Post        55
# 540  Three Billboards Outside Ebbing, Missouri       115
# 541                                 Green Book       130
# 542                              Black Panther       134
# 543                             BlacKkKlansman       135
# 544                          Bohemian Rhapsody       134
# 545                              The Favourite       119
# 546                                       Roma       120
# 547                                       Vice        87
# 548                             A Star Is Born       136
# 549                           Romeo and Juliet       138
# 550                             Les Misérables       158
# 551                                  Cleopatra       192
# 552                       Mutiny on the Bounty       178
# 553                            Heaven Can Wait       101
#
#                        Genre       Year  Winner  Biopic
# 0       Action,Drama,Romance 1927-01-01       1       0
# 1      Crime,Drama,Film-Noir 1928-01-01       0       0
# 2              Drama,Romance 1927-01-01       0       0
# 3      Drama,Musical,Romance 1929-01-01       1       0
# 4                      Crime 1929-01-01       0       0
# 5                    Musical 1929-01-01       0       0
# 6            Romance,Western 1928-01-01       0       0
# 7                      Drama 1928-01-01       0       0
# 8                  Drama,War 1930-01-01       1       0
# 9       Crime,Drama,Thriller 1930-01-01       0       0
# 10   Biography,Drama,History 1929-01-01       0       1
# 11             Drama,Romance 1930-01-01       0       0
# 12    Comedy,Musical,Romance 1929-01-01       0       0
# 13             Drama,Western 1931-01-01       1       0
# 14                     Drama 1931-01-01       0       0
# 15                    Comedy 1931-01-01       0       0
# 16       Comedy,Drama,Family 1931-01-01       0       0
# 17    Action,Adventure,Drama 1931-01-01       0       0
# 18             Drama,Romance 1932-01-01       1       0
# 19                     Drama 1931-01-01       0       0
# 20             Drama,Romance 1931-01-01       0       0
# 21               Drama,Sport 1931-01-01       0       0
# 22               Crime,Drama 1931-01-01       0       0
# 23    Comedy,Musical,Romance 1932-01-01       0       0
# 24   Adventure,Drama,Romance 1932-01-01       0       0
# 25    Comedy,Musical,Romance 1931-01-01       0       0
# 26         Drama,Romance,War 1933-01-01       1       0
# 27    Comedy,Musical,Romance 1933-01-01       0       0
# 28         Drama,Romance,War 1932-01-01       0       0
# 29     Crime,Drama,Film-Noir 1932-01-01       0       0
# ..                       ...        ...     ...     ...
# 524     Drama,Mystery,Sci-Fi 2016-01-01       0       0
# 525                    Drama 2016-01-01       0       0
# 526  Biography,Drama,History 2016-01-01       0       1
# 527       Action,Crime,Drama 2016-01-01       0       0
# 528  Biography,Drama,History 2016-01-01       0       1
# 529       Comedy,Drama,Music 2016-01-01       0       0
# 530     Comedy,Drama,Romance 2015-01-01       0       0
# 531                    Drama 2016-01-01       0       0
# 532              Documentary 2006-01-01       1       0
# 533            Drama,Romance 2017-01-01       0       0
# 534           Horror,Mystery 2005-01-01       0       0
# 535     Action,Drama,History 1958-01-01       0       0
# 536  Horror,Mystery,Thriller 2017-01-01       0       0
# 537             Comedy,Drama 2017-01-01       0       0
# 538            Drama,Romance 2017-01-01       0       0
# 539              Documentary 1999-01-01       0       0
# 540       Comedy,Crime,Drama 2017-01-01       0       0
# 541   Biography,Comedy,Drama 2018-01-01       0       1
# 542  Action,Adventure,Sci-Fi 2018-01-01       0       0
# 543    Biography,Crime,Drama 2018-01-01       0       1
# 544    Biography,Drama,Music 2018-01-01       0       1
# 545   Biography,Comedy,Drama 2018-01-01       0       1
# 546             Comedy,Drama 1972-01-01       0       0
# 547             Comedy,Drama 2000-01-01       0       0
# 548      Drama,Music,Romance 2018-01-01       0       0
# 549            Drama,Romance 1968-01-01       0       0
# 550    Drama,History,Musical 2012-01-01       0       0
# 551  Biography,Drama,History 1963-01-01       0       1
# 552  Adventure,Drama,History 1962-01-01       1       0
# 553   Comedy,Fantasy,Romance 1978-01-01       0       0
#
# [554 rows x 6 columns]

# %%
final_df.to_csv(path_or_buf='Documents')

# %% [markdown]
# # Visualizing the History of Oscar Winners

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %%
# same plotting code as above!
plt.figure(figsize=(12,3))
sns.distplot(final_df['Duration']);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %%
# same plotting code as above!
plt.figure(figsize=(12,3))
sns.distplot(final_df[final_df['Winner'] == 1]['Duration']);
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning:
#
# The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.

# %% [markdown]
# # Using WebScraping

# %%
from requests import get
url = "https://www.imdb.com/search/title?title_type=feature&groups=oscar_best_picture_nominees&view=simple&sort=year,asc&count=250"
response = get(url)
print(response.text[:500])
# Out:
# <!DOCTYPE html>
# <html
#     xmlns:og="http://ogp.me/ns#"
#     xmlns:fb="http://www.facebook.com/2008/fbml">
#     <head>
#
#         <meta charset="utf-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge">
#
#     <meta name="apple-itunes-app" content="app-id=342792525, app-argument=imdb:///?src=mdot">
#
#
#
#         <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
#
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle",

# %%
from bs4 import BeautifulSoup
html_soup = BeautifulSoup(response.text, 'html.parser')
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
movie_containers = html_soup.find_all('div', class_ = 'lister-item mode-advanced')
print(type(movie_containers))
print(len(movie_containers))
# Out:
# <class 'bs4.element.ResultSet'>
# 0

# %%
movie_containers[0].h3.a
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-114-a415f696d1a8> in <module>()
# ----> 1 movie_containers[0].h3.a
#
# IndexError: list index out of range

# %%
from time import sleep
from random import randint

# %%
pages = [str(i) for i in range(1,4)]
years_url = [str(i) for i in range(1927,2018)]

# %%
# Redeclaring the lists to store data in
names = []
years = []
imdb_ratings = []
metascores = []
votes = []

# Preparing the monitoring of the loop
start_time = time()
requests = 0

# For every year in the interval 2000-2017
for year_url in years_url:

    # For every page in the interval 1-4
    for page in pages:

        # Make a get request
        response = get('http://www.imdb.com/search/title?release_date=' + year_url +
        '&sort=num_votes,desc&page=' + page, headers = headers)

        # Pause the loop
        sleep(randint(8,15))

        # Monitor the requests
        requests += 1
        elapsed_time = time() - start_time
        print('Request:{}; Frequency: {} requests/s'.format(requests, requests/elapsed_time))
        clear_output(wait = True)

        # Throw a warning for non-200 status codes
        if response.status_code != 200:
            warn('Request: {}; Status code: {}'.format(requests, response.status_code))

        # Break the loop if the number of requests is greater than expected
        if requests > 72:
            warn('Number of requests was greater than expected.')
            break

        # Parse the content of the request with BeautifulSoup
        page_html = BeautifulSoup(response.text, 'html.parser')

        # Select all the 50 movie containers from a single page
        mv_containers = page_html.find_all('div', class_ = 'lister-item mode-advanced')

        # For every movie of these 50
        for container in mv_containers:
            # If the movie has a Metascore, then:
            if container.find('div', class_ = 'ratings-metascore') is not None:

                # Scrape the name
                name = container.h3.a.text
                names.append(name)

                # Scrape the year
                year = container.h3.find('span', class_ = 'lister-item-year').text
                years.append(year)

                # Scrape the IMDB rating
                imdb = float(container.strong.text)
                imdb_ratings.append(imdb)

                # Scrape the Metascore
                m_score = container.find('span', class_ = 'metascore').text
                metascores.append(int(m_score))

                # Scrape the number of votes
                vote = container.find('span', attrs = {'name':'nv'})['data-value']
                votes.append(int(vote))

# %%
import pandas as pd
test_df = pd.DataFrame({'movie': names,
                       'year': years,
                       'imdb': imdb_ratings,
                       'metascore': metascores,
                       'votes': votes
})
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 5 columns):
# movie        92 non-null object
# year         92 non-null object
# imdb         92 non-null float64
# metascore    63 non-null float64
# votes        92 non-null int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 3.7+ KB
# None

# %%
test_df
# Out:
#                                               movie  year  imdb  metascore  \
# 0                                           Sunrise  1927   8.2        NaN
# 1                                             Wings  1927   7.7        NaN
# 2                               The Broadway Melody  1929   6.2        NaN
# 3                    All Quiet on the Western Front  1930   8.1        NaN
# 4                                          Cimarron  1931   6.0        NaN
# 5                                       Grand Hotel  1932   7.5        NaN
# 6                                         Cavalcade  1933   6.0        NaN
# 7                             It Happened One Night  1934   8.1       87.0
# 8                              Mutiny on the Bounty  1935   7.8        NaN
# 9                                The Great Ziegfeld  1936   6.8        NaN
# 10                           The Life of Emile Zola  1937   7.3        NaN
# 11                       You Can't Take It with You  1938   8.0        NaN
# 12                               Gone with the Wind  1939   8.2       97.0
# 13                                          Rebecca  1940   8.1        NaN
# 14                          How Green Was My Valley  1941   7.8        NaN
# 15                                       Casablanca  1942   8.5      100.0
# 16                                     Mrs. Miniver  1942   7.6        NaN
# 17                                     Going My Way  1944   7.2        NaN
# 18                                 The Lost Weekend  1945   8.0        NaN
# 19                      The Best Years of Our Lives  1946   8.1       92.0
# 20                            Gentleman's Agreement  1947   7.4        NaN
# 21                                           Hamlet  1948   7.8        NaN
# 22                               All the King's Men  1949   7.5        NaN
# 23                                    All About Eve  1950   8.3       98.0
# 24                             An American in Paris  1951   7.2        NaN
# 25                       The Greatest Show on Earth  1952   6.7        NaN
# 26                            From Here to Eternity  1953   7.7        NaN
# 27                                On the Waterfront  1954   8.2       91.0
# 28                                            Marty  1955   7.7        NaN
# 29                      Around the World in 80 Days  1956   6.8        NaN
# ..                                              ...   ...   ...        ...
# 62                               Driving Miss Daisy  1989   7.4       81.0
# 63                               Dances with Wolves  1990   8.0       72.0
# 64                         The Silence of the Lambs  1991   8.6       85.0
# 65                                       Unforgiven  1992   8.2       85.0
# 66                                 Schindler's List  1993   8.9       93.0
# 67                                     Forrest Gump  1994   8.8       82.0
# 68                                       Braveheart  1995   8.4       68.0
# 69                              The English Patient  1996   7.4       87.0
# 70                                          Titanic  1997   7.8       75.0
# 71                              Shakespeare in Love  1998   7.1       87.0
# 72                                  American Beauty  1999   8.4       86.0
# 73                                        Gladiator  2000   8.5       67.0
# 74                                 A Beautiful Mind  2001   8.2       72.0
# 75                                          Chicago  2002   7.2       82.0
# 76    The Lord of the Rings: The Return of the King  2003   8.9       94.0
# 77                                            Crash  2004   7.8       69.0
# 78                              Million Dollar Baby  2004   8.1       86.0
# 79                                     The Departed  2006   8.5       85.0
# 80                           No Country for Old Men  2007   8.1       91.0
# 81                                  The Hurt Locker  2008   7.6       94.0
# 82                              Slumdog Millionaire  2008   8.0       86.0
# 83                                The King's Speech  2010   8.0       88.0
# 84                                       The Artist  2011   7.9       89.0
# 85                                             Argo  2012   7.7       86.0
# 86                                 12 Years a Slave  2013   8.1       96.0
# 87  Birdman or (The Unexpected Virtue of Ignorance)  2014   7.7       87.0
# 88                                        Spotlight  2015   8.1       93.0
# 89                                        Moonlight  2016   7.4       99.0
# 90                               The Shape of Water  2017   7.3       87.0
# 91                                       Green Book  2018   8.3       69.0
#
#       votes
# 0     42921
# 1     10059
# 2      5703
# 3     53197
# 4      4741
# 5     15576
# 6      3933
# 7     84190
# 8     18837
# 9      6354
# 10     6225
# 11    21115
# 12   262532
# 13   110126
# 14    18958
# 15   472077
# 16    14126
# 17     9248
# 18    30250
# 19    52966
# 20    13221
# 21    13801
# 22    11881
# 23   106759
# 24    27224
# 25    11523
# 26    39263
# 27   127940
# 28    19033
# 29    22021
# ..      ...
# 62    88468
# 63   219366
# 64  1121308
# 65   338117
# 66  1076405
# 67  1592539
# 68   884673
# 69   165237
# 70   948174
# 71   200258
# 72   983351
# 73  1200563
# 74   764708
# 75   199981
# 76  1478318
# 77   399359
# 78   582655
# 79  1065911
# 80   760895
# 81   390101
# 82   743097
# 83   590011
# 84   216381
# 85   531832
# 86   572463
# 87   514579
# 88   360833
# 89   224418
# 90   301598
# 91   180205
#
# [92 rows x 5 columns]
